# %% [markdown]
# Tutorial from https://www.youtube.com/watch?v=jztwpsIzEGc&t=8s,https://github.com/nicknochnack/ImageClassification/blob/main/Getting%20Started.ipynb
#
# # Set up

# %%
# Dependencies

# %pip install tensorflow tensorflow-gpu opencv-python matplotlib 
# %pip list
# Out:
# Package                        Version
# ------------------------------ ----------
# absl-py                        1.4.0
# aiofiles                       22.1.0
# aiohttp                        3.8.3
# aiosignal                      1.2.0
# aiosqlite                      0.18.0
# annotated-types                0.5.0
# anyio                          3.6.2
# argon2-cffi                    21.3.0
# argon2-cffi-bindings           21.2.0
# asgiref                        3.7.2
# asttokens                      2.0.5
# astunparse                     1.6.3
# async-timeout                  4.0.2
# attr                           0.3.1
# attrs                          22.1.0
# azure-core                     1.28.0
# azure-storage-blob             12.17.0
# Babel                          2.11.0
# backcall                       0.2.0
# beautifulsoup4                 4.12.2
# bleach                         5.0.1
# blinker                        1.6.2
# blis                           0.7.10
# boto                           2.49.0
# boto3                          1.16.63
# botocore                       1.19.63
# Bottleneck                     1.3.5
# boxing                         0.1.4
# brotlipy                       0.7.0
# cachetools                     5.3.0
# catalogue                      2.0.9
# certifi                        2023.7.22
# cffi                           1.15.1
# charset-normalizer             2.0.12
# click                          8.0.4
# cmake                          3.27.2
# comm                           0.1.2
# confection                     0.1.1
# contourpy                      1.0.5
# coreapi                        2.3.3
# coreschema                     0.0.4
# coverage                       7.2.5
# cryptography                   41.0.2
# cycler                         0.11.0
# cymem                          2.0.7
# debugpy                        1.6.6
# decorator                      5.1.1
# defusedxml                     0.7.1
# Django                         3.2.19
# django-annoying                0.10.6
# django-cors-headers            3.6.0
# django-debug-toolbar           3.2.1
# django-extensions              3.1.0
# django-filter                  2.4.0
# django-model-utils             4.1.1
# django-ranged-fileresponse     0.1.2
# django-rest-swagger            2.2.0
# django-rq                      2.5.1
# django-storages                1.12.3
# django-user-agents             0.4.0
# djangorestframework            3.13.1
# drf-dynamic-fields             0.3.0
# drf-flex-fields                0.9.5
# drf-generators                 0.3.0
# drf-yasg                       1.20.0
# entrypoints                    0.4
# executing                      0.8.3
# expiringdict                   1.2.2
# fastai                         2.7.12
# fastcore                       1.5.29
# fastdownload                   0.0.7
# fastjsonschema                 2.16.3
# fastprogress                   1.0.3
# filelock                       3.12.2
# Flask                          2.3.2
# Flask-Cors                     3.0.10
# flatbuffers                    23.5.9
# fonttools                      4.25.0
# frozenlist                     1.3.3
# gast                           0.4.0
# google-api-core                2.11.0
# google-auth                    2.14.1
# google-auth-oauthlib           1.0.0
# google-cloud-appengine-logging 1.1.0
# google-cloud-audit-log         0.2.0
# google-cloud-core              2.3.2
# google-cloud-logging           2.7.2
# google-cloud-storage           2.5.0
# google-crc32c                  1.5.0
# google-pasta                   0.2.0
# google-resumable-media         2.3.3
# googleapis-common-protos       1.56.4
# grpc-google-iam-v1             0.12.4
# grpcio                         1.54.2
# grpcio-status                  1.48.2
# h5py                           3.8.0
# htmlmin                        0.1.12
# idna                           3.4
# ijson                          3.2.2
# inflection                     0.5.1
# ipykernel                      6.25.0
# ipython                        8.12.2
# ipython-genutils               0.2.0
# ipywidgets                     8.0.4
# isodate                        0.6.1
# itsdangerous                   2.1.2
# itypes                         1.2.0
# jax                            0.4.10
# jedi                           0.18.1
# Jinja2                         3.1.2
# jmespath                       0.10.0
# joblib                         1.2.0
# json5                          0.9.11
# jsonschema                     4.17.3
# jupyter                        1.0.0
# jupyter_client                 8.1.0
# jupyter-console                6.6.3
# jupyter_core                   5.3.0
# jupyter-events                 0.6.3
# jupyter_server                 2.5.0
# jupyter_server_fileid          0.9.0
# jupyter_server_terminals       0.4.4
# jupyter_server_ydoc            0.8.0
# jupyter-ydoc                   0.2.4
# jupyterlab                     3.6.3
# jupyterlab-pygments            0.1.2
# jupyterlab_server              2.22.0
# jupyterlab-widgets             3.0.5
# kaggle                         1.5.16
# keras                          2.13.1
# Keras-Preprocessing            1.1.2
# kiwisolver                     1.4.4
# label-studio                   1.8.1
# label-studio-converter         0.0.54rc0
# label-studio-tools             0.0.2
# langcodes                      3.3.0
# launchdarkly-server-sdk        7.5.0
# libclang                       16.0.0
# lit                            16.0.6
# lockfile                       0.12.2
# lxml                           4.9.2
# Markdown                       3.4.3
# markdown-it-py                 2.2.0
# MarkupSafe                     2.1.1
# matplotlib                     3.7.1
# matplotlib-inline              0.1.6
# mdurl                          0.1.2
# mistune                        2.0.5
# mkl-fft                        1.3.6
# mkl-random                     1.2.2
# mkl-service                    2.4.0
# ml-dtypes                      0.1.0
# mpmath                         1.3.0
# multidict                      6.0.2
# munkres                        1.1.4
# murmurhash                     1.0.9
# nbclassic                      0.5.3
# nbclient                       0.5.13
# nbconvert                      7.2.10
# nbformat                       5.8.0
# nest-asyncio                   1.5.6
# networkx                       3.1
# nltk                           3.6.7
# notebook                       6.5.3
# notebook_shim                  0.2.2
# numexpr                        2.8.4
# numpy                          1.24.3
# nvidia-cublas-cu11             11.10.3.66
# nvidia-cuda-cupti-cu11         11.7.101
# nvidia-cuda-nvrtc-cu11         11.7.99
# nvidia-cuda-runtime-cu11       11.7.99
# nvidia-cudnn-cu11              8.5.0.96
# nvidia-cufft-cu11              10.9.0.58
# nvidia-curand-cu11             10.2.10.91
# nvidia-cusolver-cu11           11.4.0.1
# nvidia-cusparse-cu11           11.7.4.91
# nvidia-nccl-cu11               2.14.3
# nvidia-nvtx-cu11               11.7.91
# oauthlib                       3.2.2
# openapi-codec                  1.3.2
# opencv-python                  4.7.0.72
# opt-einsum                     3.3.0
# ordered-set                    4.0.2
# packaging                      23.0
# pandas                         2.0.3
# pandocfilters                  1.5.0
# parso                          0.8.3
# pathy                          0.10.2
# pexpect                        4.8.0
# pickleshare                    0.7.5
# Pillow                         9.4.0
# pip                            23.1.2
# pkginfo                        1.9.6
# platformdirs                   3.10.0
# ply                            3.11
# preshed                        3.0.8
# prometheus-client              0.16.0
# prompt-toolkit                 3.0.36
# proto-plus                     1.22.3
# protobuf                       3.20.3
# psutil                         5.9.0
# psycopg2-binary                2.9.6
# ptyprocess                     0.7.0
# pure-eval                      0.2.2
# pyarrow                        12.0.0
# pyasn1                         0.4.8
# pyasn1-modules                 0.2.8
# pycparser                      2.21
# pydantic                       2.3.0
# pydantic_core                  2.6.3
# Pygments                       2.15.1
# PyJWT                          2.4.0
# pyOpenSSL                      23.2.0
# pyparsing                      3.0.9
# PyQt5-sip                      12.11.0
# pyrsistent                     0.18.0
# PySocks                        1.7.1
# pytest-cov                     4.0.0
# python-dateutil                2.8.2
# python-json-logger             2.0.4
# python-slugify                 8.0.1
# pytz                           2022.7
# PyYAML                         6.0
# pyzmq                          25.0.2
# qtconsole                      5.4.2
# QtPy                           2.2.0
# readme-renderer                37.3
# redis                          3.5.3
# regex                          2023.6.3
# requests                       2.31.0
# requests-oauthlib              1.3.1
# requests-toolbelt              1.0.0
# rfc3339-validator              0.1.4
# rfc3986                        2.0.0
# rfc3986-validator              0.1.1
# rich                           13.3.5
# rq                             1.10.1
# rsa                            4.9
# ruamel.yaml                    0.17.32
# ruamel.yaml.clib               0.2.7
# rules                          2.2
# s3transfer                     0.3.7
# scikit-learn                   1.3.0
# scipy                          1.11.1
# seaborn                        0.12.2
# semver                         2.13.0
# Send2Trash                     1.8.0
# sentry-sdk                     1.28.0
# setuptools                     68.0.0
# sip                            6.6.2
# six                            1.16.0
# smart-open                     6.3.0
# sniffio                        1.3.0
# soupsieve                      2.4
# spacy                          3.6.1
# spacy-legacy                   3.0.12
# spacy-loggers                  1.0.4
# sqlparse                       0.4.4
# srsly                          2.4.7
# stack-data                     0.2.0
# sympy                          1.12
# tensorboard                    2.13.0
# tensorboard-data-server        0.7.0
# tensorboard-plugin-wit         1.8.1
# tensorflow                     2.13.0
# tensorflow-estimator           2.13.0
# tensorflow-io-gcs-filesystem   0.32.0
# termcolor                      2.3.0
# terminado                      0.17.1
# text-unidecode                 1.3
# Theano                         0.7.0
# thinc                          8.1.12
# threadpoolctl                  2.2.0
# tinycss2                       1.2.1
# toml                           0.10.2
# tomli                          2.0.1
# torch                          2.0.1
# torchvision                    0.15.2
# tornado                        6.2
# tqdm                           4.66.1
# traitlets                      5.9.0
# triton                         2.0.0
# twine                          4.0.2
# typer                          0.9.0
# typing_extensions              4.7.1
# tzdata                         2023.3
# ua-parser                      0.18.0
# uri-template                   1.2.0
# uritemplate                    4.1.1
# urllib3                        1.26.16
# user-agents                    2.2.0
# wasabi                         1.1.2
# wcwidth                        0.2.5
# webcolors                      1.12
# webencodings                   0.5.1
# websocket-client               1.5.1
# Werkzeug                       2.3.4
# wheel                          0.40.0
# widgetsnbextension             4.0.5
# wrapt                          1.14.1
# xmljson                        0.2.0
# y-py                           0.5.9
# yarl                           1.8.1
# ypy-websocket                  0.8.2
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports
import tensorflow as tf
import os
# Out:
# 2023-08-28 16:43:06.464812: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-28 16:43:14.872685: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-28 16:43:42.076521: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Avoid OOM (out of memory) errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True) # to only what is needed
tf.config.list_physical_devices('GPU')
# Out:
# 2023-08-28 16:45:54.110487: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-28 16:45:54.158299: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-28 16:45:54.158419: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Load Data

# %%
import cv2
import imghdr

# Browswer extension to download all images from the web: https://chrome.google.com/webstore/detail/download-all-images/ifipmflagepipjokmbdecpmjbibjnakm 

data_dir = 'data' 

image_exts = ['jpeg','jpg', 'bmp', 'png']

for image_class in os.listdir(data_dir): 
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)
